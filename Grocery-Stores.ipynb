# %% [markdown]
# # Submetric Groceries and Convenience store loactions

# %% [markdown]
# Why this metric:
# We choose this metric because being able to have easy access to food is a important part of convenience when looking at how far out a person's way they would have to go to meet basic necessities.

# %%
import pandas as pd

stores = pd.read_csv("Grocery-data.tsv", sep='\t')

stores.head()
# Out:
#       Client ID                               Name  \
# 0  201211150002                        Avalon Fuel
# 1  201511040005     Ez Energy #303/7Eleven #36183H
# 2  201212130003  EZ Energy #311 / 7 Eleven #36191H
# 3  201211190006     Getgo #3646 / Crafton - Ingram
# 4         53583                   Mt NeBlvd Texaco
#
#                        Legal Name  Start Date Street #  \
# 0             Avalon Fuel Company  10/26/2012      901
# 1  Neelkanth Ansh Enterprises Inc  10/26/2015      209
# 2                    7 Eleven Inc   12/3/2012     8136
# 3                 Giant Eagle Inc  11/15/2012      280
# 4                Mt NeBlvd Texaco    6/2/1995     1706
#
#                       Street Name State      Zip        Lat        Lon  \
# 0                 Ohio River Blvd    PA  15202.0  40.495759 -80.066508
# 1                 Ohio River Blvd    PA  15143.0  40.545418 -80.194152
# 2                 Ohio River Blvd    PA  15202.0  40.510522 -80.094268
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt




codes = pd.read_csv("Grocery-data.tsv", sep="\t")
unique= codes['Zip'].value_counts().rename_axis('Zip Codes').to_frame(name='Store Count')

#data = unique.value_counts().rename_axis('Zip Codes').to_frame(name='Store Count')
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)


#print(data)

unique.plot.bar(figsize=(20, 15))

unique.head(10)
# Out:
#            Store Count
# Zip Codes
# 15237.0             28
# 15146.0             22
# 15222.0             21
# 15132.0             19
# 15108.0             19
# 15210.0             18
# 15213.0             17
# 15136.0             17
# 15212.0             17
# 15219.0             17

# %% [markdown]
# Mcknight- 28
# Strip District- 21
# Monroville- 22

# %% [markdown]
# To conclude the data of who has the most convenience stores and grocery stores the top three neighborhoods go to the Mcknight, the Strip District, and Monroville. The top neighborhood for this submetric with 28 different stores is Mcknight. Following that is Monroeville which is futher out towords Pennhills with a count of 22. And in third is the Strip District with a total of 21. So for this submetric Mcknight wins out with the largest total stores with 28 in the area.
