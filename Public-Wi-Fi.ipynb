# %% [markdown]
# # Submetric Public Wifi Locations

# %% [markdown]
# Why this Metric:
# We choose this metric becuase in todays age being able to connect to the internet is a large part of being able to connect to the world. This is espically true for people who may not be able to afford having home wi-fi. Having public wi-fi is a great convenice to people espically if its free and easy to access.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt




codes = pd.read_csv("Wifi-data.tsv", sep="\t")
unique= codes['zip'].value_counts().rename_axis('Zip Codes').to_frame(name='Wifi Count')

#data = unique.value_counts().rename_axis('Zip Codes').to_frame(name='Store Count')
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)


#print(data)

unique.plot.bar()

unique.head(90)
# Out:
#            Wifi Count
# Zip Codes
# 15104.0            18
# 15210.0            13
# 15219.0             9
# 15215.0             8
# 15203.0             6
# 15213.0             5
# 15235.0             5
# 15226.0             4
# 15216.0             4
# 15221.0             3
# 15217.0             3
# 15205.0             3
# 15227.0             3
# 15025.0             2
# 15218.0             2
# 15110.0             2
# 15137.0             2
# 15108.0             2
# 15236.0             2
# 15209.0             2
# 15212.0             2
# 15207.0             2
# 15202.0             2
# 15106.0             2
# 15220.0             2
# 15144.0             1
# 15143.0             1
# 15206.0             1
# 15116.0             1
# 15064.0             1
# 15129.0             1
# 15017.0             1
# 15136.0             1
# 15239.0             1
# 15071.0             1
# 15234.0             1
# 15044.0             1
# 15131.0             1
# 15241.0             1
# 15139.0             1
# 15238.0             1
# 15208.0             1
# 15237.0             1
# 15201.0             1
# 15228.0             1
# 15146.0             1
# 15204.0             1
# 15132.0             1
# 15120.0             1
# 15101.0             1
# 15065.0             1
# 15102.0             1
# 15233.0             1

# %% [markdown]
# Braddock- 18
# Mt Oliver- 13
# Central Business District- 9

# %% [markdown]
# When it comes to public wifi the top neighborhoods to find it free and easy to access are Braddock, Mt. Oliver, and The Central Business District. Coming in at the top is Braddock with 18 public locations followed by Mt Oliver with a total of 13. Finally in third we have the Central Business District with a total of 9 differnt spots. To conclude when it comes to the metric of public wifi Braddock comes in as the most conveient with a total of 18 different locations.
