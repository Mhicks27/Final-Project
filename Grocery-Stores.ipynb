# %% [markdown]
# # Submetric Groceries and Convenience store loactions

# %% [markdown]
# Why this metric:
# We choose this metric because being able to have easy access to food is a important part of conveience when looking at how far out a persons way they would have to go to meet basic nessities. |

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt




codes = pd.read_csv("Grocery-data.tsv", sep="\t")
unique= codes['Zip'].value_counts().rename_axis('Zip Codes').to_frame(name='Store Count')

#data = unique.value_counts().rename_axis('Zip Codes').to_frame(name='Store Count')
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)


#print(data)

unique.plot.bar()

unique.head(90)
# Out:
#            Store Count
# Zip Codes
# 15237.0             28
# 15146.0             22
# 15222.0             21
# 15132.0             19
# 15108.0             19
# 15210.0             18
# 15213.0             17
# 15136.0             17
# 15212.0             17
# 15219.0             17
# 15206.0             17
# 15235.0             16
# 15221.0             16
# 15236.0             16
# 15205.0             15
# 15227.0             15
# 15122.0             15
# 15090.0             12
# 15044.0             12
# 15217.0             11
# 15147.0             11
# 15224.0             11
# 15102.0             10
# 15120.0             10
# 15202.0              9
# 15137.0              9
# 15106.0              9
# 15238.0              9
# 15229.0              9
# 15017.0              9
# 15220.0              8
# 15071.0              8
# 15203.0              8
# 15218.0              8
# 15131.0              8
# 15037.0              8
# 15226.0              8
# 15101.0              8
# ...

# %% [markdown]
# Mcknight- 28
# Strip District- 21
# Monroville- 22

# %% [markdown]
# To conclude the data of who has the most convenience stores and grocery stores the top three neighborhoods go to the Mckight, The Strip District, and Monroville. The top neighborhood for this submetric with 28 different stores is Mckinght. Following that is Monrovillve which is futher out twords Pennhills with a count of 22. And in third is the Strip District with a total of 21. So for this submetric Mcknight wins out with the largest total stores with 28 in the area.
